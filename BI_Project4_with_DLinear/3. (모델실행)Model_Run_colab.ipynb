# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os
os.chdir('/content/drive/MyDrive/work_space/Project/BI_Competition/BI_Project4_with_DLinear')
import torch
import random
import argparse
from exp.exp_main import Exp_Main
from utils2.Date_Processor import *
from utils2.Data_run import arg_set, model_run

# %%
result_df = pd.read_csv('./Data_Preprocessed(전처리 데이터)/Final_Preprocessed_Data.csv')

# %%
fix_seed = 42
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

# %%
data_path = './Data_Final(실제 모델 입력데이터)/1_year'
data_list = os.listdir(data_path)

for i in data_list:
    folder_data = data_path
    data = i

    args = arg_set(folder_data, data, model_name = 'colab')
    model_run(args)

# %%
data_path = './Data_Final(실제 모델 입력데이터)/2_year'
data_list = os.listdir(data_path)

for i in data_list:
    folder_data = data_path
    data = i

    args = arg_set(folder_data, data, model_name = 'colab')
    model_run(args)

# %%
data_path = './Data_Final(실제 모델 입력데이터)/3_year'
data_list = os.listdir(data_path)

for i in data_list:
    folder_data = data_path
    data = i

    args = arg_set(folder_data, data, model_name = 'colab')
    model_run(args)

# %%
data_path = './Data_Final(실제 모델 입력데이터)/predict_period'
data_list = os.listdir(data_path)[18:]
data_list
# Out:
# ['2020-03-17_12-00-00__2023-03-17_11-55-00_result.csv',
#  '2020-03-17_18-00-00__2023-03-17_17-55-00_result.csv',
#  '2020-03-18_00-00-00__2023-03-17_23-55-00_result.csv',
#  '2020-03-18_06-00-00__2023-03-18_05-55-00_result.csv',
#  '2020-03-18_12-00-00__2023-03-18_11-55-00_result.csv',
#  '2020-03-18_18-00-00__2023-03-18_17-55-00_result.csv',
#  '2020-03-19_00-00-00__2023-03-18_23-55-00_result.csv',
#  '2020-03-19_06-00-00__2023-03-19_05-55-00_result.csv',
#  '2020-03-19_12-00-00__2023-03-19_11-55-00_result.csv',
#  '2020-03-19_18-00-00__2023-03-19_17-55-00_result.csv']

# %%
for i in data_list:
    folder_data = data_path
    data = i

    args = arg_set(folder_data, data, model_name='cloc')
    model_run(args)
# Out:
# Epoch: 3, Steps: 13738 | Train Loss: 0.1950930 Vali Loss: 0.2971886 Test Loss: 0.1947994
# Validation loss decreased (0.300638 --> 0.297189).  Saving model ...
# Updating learning rate to 0.00025
# 	iters: 100, epoch: 4 | loss: 0.1900757
# 	speed: 0.3662s/iter; left time: 10025.1669s
# 	iters: 200, epoch: 4 | loss: 0.1595663
# 	speed: 0.0060s/iter; left time: 164.3612s
# 	iters: 300, epoch: 4 | loss: 0.2050564
# 	speed: 0.0054s/iter; left time: 146.2193s
# 	iters: 400, epoch: 4 | loss: 0.3540991
# 	speed: 0.0053s/iter; left time: 143.1648s
# 	iters: 500, epoch: 4 | loss: 0.4952842
# 	speed: 0.0055s/iter; left time: 149.6481s
# 	iters: 600, epoch: 4 | loss: 0.1319891
# 	speed: 0.0055s/iter; left time: 147.8300s
# 	iters: 700, epoch: 4 | loss: 0.1719578
# 	speed: 0.0054s/iter; left time: 145.7936s
# 	iters: 800, epoch: 4 | loss: 0.1462776
# 	speed: 0.0056s/iter; left time: 149.2547s
# 	iters: 900, epoch: 4 | loss: 0.1510628
# 	speed: 0.0056s/iter; left time: 148.7055s
# ...
