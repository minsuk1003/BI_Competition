# %%
import pandas as pd
import numpy as np
import collections

# %%
raw_df = pd.read_csv('/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/work_space/Project_Files/BI공모전/분석과제 5/제11회 산업통상자원부 공공데이터활용 BI공모전_빅데이터 분석 과제 5_데이터.csv')

# %%
raw_df = raw_df[:7676]

# %%
collections.Counter(raw_df.구분1)
# Out:
# Counter({'실측': 3838, '예측': 3838})

# %%
raw_df.sort_values(by='일자')
# Out:
#                일자 구분1  발전소코드  발전소용량(KW)   0:00  1:00  2:00  3:00 4:00  5:00  \
# 0      2023-03-01  실측  G1053     249.48   0.00  0.00     0     0    0  0.00
# 8804   2023-03-01  실측  V9001     998.20   0.00  0.00     0     0    0  0.00
# 8805   2023-03-01  실측  V9002     998.20   0.00  0.00     0     0    0  0.00
# 8806   2023-03-01  실측  V9003    1480.50   0.00  0.00     0     0    0  0.00
# 8807   2023-03-01  실측  V9004    2708.61   0.00  0.00     0     0    0  0.00
# ...           ...  ..    ...        ...    ...   ...   ...   ...  ...   ...
# 7509   2023-03-31  예측  G1060     498.96   0.63  0.73  0.66  0.63  0.6  0.61
# 7508   2023-03-31  실측  G1060     498.96  35.40  0.00     0     0    0  0.00
# 7507   2023-03-31  예측  G1021     496.00   0.00  0.00     0     0    0  0.00
# 10245  2023-03-31  실측  V9002     998.20   0.00  0.00     0     0    0  0.00
# 10263  2023-03-31  실측  V9020    2801.00   0.00  0.00     0     0    0  0.00
#
# ...

# %%
raw_df
# Out:
#               일자 구분1  발전소코드  발전소용량(KW)   0:00  1:00   2:00  3:00  4:00  5:00  \
# 0     2023-03-01  실측  G1053     249.48   0.00  0.00      0     0     0  0.00
# 1     2023-03-01  예측  G1053     249.48   0.95  0.97   0.94  0.97  0.96  0.95
# 2     2023-03-01  실측  G1018     288.00   0.00  0.00      0     0     0  0.00
# 3     2023-03-01  예측  G1018     288.00   0.00  0.00      0     0     0  0.00
# 4     2023-03-01  실측  G1034     298.08  12.40  0.00      0     0     0  0.00
# ...          ...  ..    ...        ...    ...   ...    ...   ...   ...   ...
# 7671  2023-03-31  예측  S5036    2997.00   9.73  9.58  10.21  9.15  9.41  8.82
# 7672  2023-03-31  실측  S5044    2997.00   0.00  0.00      0     0     0  0.00
# 7673  2023-03-31  예측  S5044    2997.00  10.48  9.85   9.79  9.24  8.92  8.97
# 7674  2023-03-31  실측  B1735    5587.56   0.00  0.00      0     0     0  0.00
# 7675  2023-03-31  예측  B1735    5587.56   8.42  9.11   9.07  8.88   7.8  7.81
#
# ...

# %%
raw_df.columns
# Out:
# Index(['일자', '구분1', '발전소코드', '발전소용량(KW)', '0:00', '1:00', '2:00', '3:00',
#        '4:00', '5:00', '6:00', '7:00', '8:00', '9:00', '10:00', '11:00',
#        '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00',
#        '20:00', '21:00', '22:00', '23:00', '합계'],
#       dtype='object')

# %%
columns_name = ['Date', 'Real', 'Power_Code', 'Power_Volume(kW)', '0:00_Real', '1:00_Real', '2:00_Real', '3:00_Real',
       '4:00_Real', '5:00_Real', '6:00_Real', '7:00_Real', '8:00_Real', '9:00_Real', '10:00_Real', '11:00_Real',
       '12:00_Real', '13:00_Real', '14:00_Real', '15:00_Real', '16:00_Real', '17:00_Real', '18:00_Real', '19:00_Real',
       '20:00_Real', '21:00_Real', '22:00_Real', '23:00_Real', 'Sum_Real', '0:00_Pred', '1:00_Pred', '2:00_Pred', '3:00_Pred',
       '4:00_Pred', '5:00_Pred', '6:00_Pred', '7:00_Pred', '8:00_Pred', '9:00_Pred', '10:00_Pred', '11:00_Pred',
       '12:00_Pred', '13:00_Pred', '14:00_Pred', '15:00_Pred', '16:00_Pred', '17:00_Pred', '18:00_Pred', '19:00_Pred',
       '20:00_Pred', '21:00_Pred', '22:00_Pred', '23:00_Pred', 'Sum_Pred']

# %%
X = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, 4:]])
X_data = pd.DataFrame(data=X, columns = columns_name)
X_data.drop('Real', axis=1, inplace=True)
X_data
# Out:
#             Date Power_Code Power_Volume(kW) 0:00_Real 1:00_Real 2:00_Real  \
# 0     2023-03-01      G1053           249.48       0.0       0.0         0
# 1     2023-03-01      G1018            288.0       0.0       0.0         0
# 2     2023-03-01      G1034           298.08      12.4       0.0         0
# 3     2023-03-01      S5004            300.8       0.0       0.0         0
# 4     2023-03-01      S5043           320.76       0.0       0.0         0
# ...          ...        ...              ...       ...       ...       ...
# 3833  2023-03-31      S5045           2995.2       9.6       0.0         0
# 3834  2023-03-31      B1736           2995.2       0.0       0.0         0
# 3835  2023-03-31      S5036           2997.0       0.0       0.0         0
# 3836  2023-03-31      S5044           2997.0       0.0       0.0         0
# 3837  2023-03-31      B1735          5587.56       0.0       0.0         0
#
# ...

# %%
X_data.to_csv('/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/work_space/Project_Files/BI공모전/분석과제 5/total.csv', index=False)
X_data.to_excel('/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/work_space/Project_Files/BI공모전/분석과제 5/total.xlsx', index=False)
